# %% [markdown]
# ## Install Packages

# %%
try:
    import pymongo
except:
    # !pip install pymongo

# %% [markdown]
# ## Conncet to MongoDB

# %%
from pymongo import MongoClient
client = MongoClient('localhost:27017', 
                        username='root',
                         password='example')

# %% [markdown]
# ## list of all databases

# %%
for db in client.list_databases():
    print(db)
# Out:
# {'name': 'Ahmad', 'sizeOnDisk': 73728.0, 'empty': False}
# {'name': 'admin', 'sizeOnDisk': 172032.0, 'empty': False}
# {'name': 'config', 'sizeOnDisk': 36864.0, 'empty': False}
# {'name': 'local', 'sizeOnDisk': 73728.0, 'empty': False}
# {'name': 'mydb', 'sizeOnDisk': 65536.0, 'empty': False}
# {'name': 'sarah', 'sizeOnDisk': 65536.0, 'empty': False}
# {'name': 'walid', 'sizeOnDisk': 81920.0, 'empty': False}

# %%
for db in client.list_database_names():
    print(db)
# Out:
# Ahmad
# admin
# config
# local
# mydb
# sarah
# walid

# %% [markdown]
# ## Create DataBase

# %%
db = client['covid19_db2020']

# %% [markdown]
# ## Create Collection

# %%
cases = db['cases_col_2020']

# %% [markdown]
# ## Read json file

# %%
# !ls data_json |wc -l
# Out:
# 35502

# %%
# !ls data_json | head -n 10
# Out:
# 0.json
# 1.json
# 10.json
# 100.json
# 1000.json
# 10000.json
# 10001.json
# 10002.json
# 10003.json
# 10004.json
# ls: write error

# %%
import json 
with open('data_json/1.json', 'r') as f:
    file_dict=json.loads(json.load(f))

# %%
file_dict
# Out:
# {'Date': '3/8/2020',
#  'Country_Region': 'India',
#  'Province_State': None,
#  'Difference': 0,
#  'Prep_Flow_Runtime': '3/24/2020 9:39:03 AM',
#  'Latest_Date': '3/23/2020',
#  'Case_Type': 'Deaths',
#  'Cases': 0,
#  'Lat': 21.0,
#  'Long': 78.0,
#  'Index': 1}

# %%
# !ls data_json | wc -l
# Out:
# 35502

# %% [markdown]
# # Push documents to collection

# %%
result = cases.insert_one(file_dict)

# %% [markdown]
# # Push all files

# %%
import glob

List=glob.glob('data_json/*.json')

# %%
List[0:10]
# Out:
# ['data_json\\0.json',
#  'data_json\\1.json',
#  'data_json\\10.json',
#  'data_json\\100.json',
#  'data_json\\1000.json',
#  'data_json\\10000.json',
#  'data_json\\10001.json',
#  'data_json\\10002.json',
#  'data_json\\10003.json',
#  'data_json\\10004.json']

# %%
len(List)
# Out:
# 35502

# %%
from tqdm import tqdm
for file in tqdm(List[1:1001]):
    with open(file, 'r') as f:
        file_dict=json.loads(json.load(f))
        
    result = cases.insert_one(file_dict)
# Out:
# 100%|██████████| 1000/1000 [00:16<00:00, 59.82it/s]

# %% [markdown]
# ## Return all the documents in a collection in mongodb

# %%
cursor = cases.find({'Country_Region': 'India'})
for document in cursor:
    print(document)
# Out:
# {'_id': ObjectId('607c55428f662e2f5f75fa7c'), 'Date': '3/8/2020', 'Country_Region': 'India', 'Province_State': None, 'Difference': 0, 'Prep_Flow_Runtime': '3/24/2020 9:39:03 AM', 'Latest_Date': '3/23/2020', 'Case_Type': 'Deaths', 'Cases': 0, 'Lat': 21.0, 'Long': 78.0, 'Index': 1}
# {'_id': ObjectId('607c55c98f662e2f5f75fa7d'), 'Date': '3/8/2020', 'Country_Region': 'India', 'Province_State': None, 'Difference': 0, 'Prep_Flow_Runtime': '3/24/2020 9:39:03 AM', 'Latest_Date': '3/23/2020', 'Case_Type': 'Deaths', 'Cases': 0, 'Lat': 21.0, 'Long': 78.0, 'Index': 1}
# {'_id': ObjectId('607c55c98f662e2f5f75fa7e'), 'Date': '3/20/2020', 'Country_Region': 'India', 'Province_State': None, 'Difference': 1, 'Prep_Flow_Runtime': '3/24/2020 9:39:03 AM', 'Latest_Date': '3/23/2020', 'Case_Type': 'Deaths', 'Cases': 5, 'Lat': 21.0, 'Long': 78.0, 'Index': 10}
# {'_id': ObjectId('607c55c98f662e2f5f75fa7f'), 'Date': '2/20/2020', 'Country_Region': 'India', 'Province_State': None, 'Difference': 0, 'Prep_Flow_Runtime': '3/24/2020 9:39:03 AM', 'Latest_Date': '3/23/2020', 'Case_Type': 'Confirmed', 'Cases': 3, 'Lat': 21.0, 'Long': 78.0, 'Index': 100}
# {'_id': ObjectId('607c55cb8f662e2f5f75faee'), 'Date': '2/2/2020', 'Country_Region': 'India', 'Province_State': None, 'Difference': 1, 'Prep_Flow_Runtime': '3/24/2020 9:39:03 AM', 'Latest_Date': '3/23/2020', 'Case_Type': 'Confirmed', 'Cases': 2, 'Lat': 21.0, 'Long': 78.0, 'Index': 101}
# {'_id': ObjectId('607c55cd8f662e2f5f75fb5d'), 'Date': '2/19/2020', 'Country_Region': 'India', 'Province_State': None, 'Difference': 0, 'Prep_Flow_Runtime': '3/24/2020 9:39:03 AM', 'Latest_Date': '3/23/2020', 'Case_Type': 'Confirmed', 'Cases': 3, 'Lat': 21.0, 'Long': 78.0, 'Index': 102}
# {'_id': ObjectId('607c55cf8f662e2f5f75fbcc'), 'Date': '2/18/2020', 'Country_Region': 'India', 'Province_State': None, 'Difference': 0, 'Prep_Flow_Runtime': '3/24/2020 9:39:03 AM', 'Latest_Date': '3/23/2020', 'Case_Type': 'Confirmed', 'Cases': 3, 'Lat': 21.0, 'Long': 78.0, 'Index': 103}
# {'_id': ObjectId('607c55d08f662e2f5f75fc3b'), 'Date': '2/17/2020', 'Country_Region': 'India', 'Province_State': None, 'Difference': 0, 'Prep_Flow_Runtime': '3/24/2020 9:39:03 AM', 'Latest_Date': '3/23/2020', 'Case_Type': 'Confirmed', 'Cases': 3, 'Lat': 21.0, 'Long': 78.0, 'Index': 104}
# {'_id': ObjectId('607c55d28f662e2f5f75fcaa'), 'Date': '2/16/2020', 'Country_Region': 'India', 'Province_State': None, 'Difference': 0, 'Prep_Flow_Runtime': '3/24/2020 9:39:03 AM', 'Latest_Date': '3/23/2020', 'Case_Type': 'Confirmed', 'Cases': 3, 'Lat': 21.0, 'Long': 78.0, 'Index': 105}
# {'_id': ObjectId('607c55d48f662e2f5f75fd19'), 'Date': '2/15/2020', 'Country_Region': 'India', 'Province_State': None, 'Difference': 0, 'Prep_Flow_Runtime': '3/24/2020 9:39:03 AM', 'Latest_Date': '3/23/2020', 'Case_Type': 'Confirmed', 'Cases': 3, 'Lat': 21.0, 'Long': 78.0, 'Index': 106}
# {'_id': ObjectId('607c55d78f662e2f5f75fd88'), 'Date': '2/14/2020', 'Country_Region': 'India', 'Province_State': None, 'Difference': 0, 'Prep_Flow_Runtime': '3/24/2020 9:39:03 AM', 'Latest_Date': '3/23/2020', 'Case_Type': 'Confirmed', 'Cases': 3, 'Lat': 21.0, 'Long': 78.0, 'Index': 107}
# {'_id': ObjectId('607c55d88f662e2f5f75fdf7'), 'Date': '2/13/2020', 'Country_Region': 'India', 'Province_State': None, 'Difference': 0, 'Prep_Flow_Runtime': '3/24/2020 9:39:03 AM', 'Latest_Date': '3/23/2020', 'Case_Type': 'Confirmed', 'Cases': 3, 'Lat': 21.0, 'Long': 78.0, 'Index': 108}

# %%
cursor = cases.find({})
Locations=[]
Name=[]
for document in tqdm(cursor):
    #print(document['Lat'],document['Long'],document['Case_Type'])
    Locations.append([document['Lat'],document['Long']])
    Name.append(document['Case_Type'])
# Out:
# 1000it [00:00, 63345.63it/s]

# %%
import folium
map = folium.Map(location=[38.9, -77.05], zoom_start=8)
folium.Marker([38.9, -77.05], 
                  popup='PSUT is the best'
                  ).add_to(map)
folium.Marker([38.9, -77.2], 
                  popup='PSUT is the best always'
                  ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_832c3d1efd6b4f1fa85afbfd285de2f8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_832c3d1efd6b4f1fa85afbfd285de2f8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_832c3d1efd6b4f1fa85afbfd285de2f8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_832c3d1efd6b4f1fa85afbfd285de2f8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.9%2C%20-77.05%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
import folium
map = folium.Map(location=[38.9, -77.05], zoom_start=2)
for point in range(0, len(Name)):
    folium.Marker(Locations[point], 
                  popup=Name[point]
                  ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3e0ad0da77974a599a9b5a331e31f605%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3e0ad0da77974a599a9b5a331e31f605%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3e0ad0da77974a599a9b5a331e31f605%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3e0ad0da77974a599a9b5a331e31f605%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.9%2C%20-77.05%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
import folium
map = folium.Map(location=[38.9, -77.05],tiles="Stamen Terrain", zoom_start=2)
for point in range(0, len(Name)):
    folium.Marker(Locations[point], 
                  popup=Name[point]
                  ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ed4db959813c40b49be6bd8c650ca98a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ed4db959813c40b49be6bd8c650ca98a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ed4db959813c40b49be6bd8c650ca98a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ed4db959813c40b49be6bd8c650ca98a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.9%2C%20-77.05%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
import folium
map = folium.Map(location=[38.9, -77.05],tiles="Stamen Toner", zoom_start=2)
for point in range(0, len(Name)):
    folium.Marker(Locations[point], 
                  popup=Name[point]
                  ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7da284212cea44cc944b87b2ab91546e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7da284212cea44cc944b87b2ab91546e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7da284212cea44cc944b87b2ab91546e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7da284212cea44cc944b87b2ab91546e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.9%2C%20-77.05%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
map.save('CovideCases.html')

# %%
# !du -sh data_json
# Out:
# 49M	data_json
